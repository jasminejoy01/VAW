# %% [markdown]
# <a href="https://colab.research.google.com/github/jasminejoy01/VAW/blob/main/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('adv-ele-dataset.csv')

# %%
df
# Out:
#                                                   Input  \
# 0     The Seattle-based company has applied for its ...
# 1     Until now, the differences between commercial,...
# 2     Amazon has applied for dozens of new domains, ...
# 3     Allowing private companies to register geograp...
# 4     Brazil said its views were endorsed last month...
# ...                                                 ...
# 2161  The charity National Trust, which employs many...
# 2162  Our properties have told us its important to b...
# 2163  While some employees welcome the  exibility of...
# 2164  The institutes  gures also suggest that 17% of...
# 2165  Industries where employers were most likely to...
#
#                                                  Target
# 0     Amazon has asked for its company name to be a ...
# 1     Until now, the differences between commercial,...
# 2     Amazon has applied for many new domains, inclu...
# 3     Allowing private companies to register geograp...
# ...

# %%
sent = df.loc[0]['Input']

# %%
sent
# Out:
# 'The Seattle-based company has applied for its brand to be a top-level domain name (currently .com), but the South American governments argue this would prevent the use of this internet address for environmental protection, the promotion of indigenous rights and other public interest uses.'

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 29.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead

# %%
model_name = 'gpt2'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
input_ids = tokenizer.encode(sent)

# %%
len(input_ids)
# Out:
# 53

# %%
# tokenizer.convert_ids_to_tokens(input_ids)

# %%
# for id_ in input_ids:
#   print(id_, tokenizer.convert_ids_to_tokens(id_))

# %%
df['combined'] = ['<s>' + x + '</s>' + '[SIMP]' + '<o>' + y + '</o>' for x,y in zip(df['Input'], df['Target'])]

# %%
df.iloc[0]['combined']
# Out:
# '<s>The Seattle-based company has applied for its brand to be a top-level domain name (currently .com), but the South American governments argue this would prevent the use of this internet address for environmental protection, the promotion of indigenous rights and other public interest uses.</s>[SIMP]<o>Amazon has asked for its company name to be a top-level domain name (currently .com), but the South American governments say this would stop the use of this internet address for environmental protection, indigenous rights and other public interest uses.</o>'
